# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print('Setup complete')
# Out:
# Setup complete

# %%
insurance = pd.read_csv('insurance.csv')

# %%
insurance =pd.read_csv('insurance.csv', index_col= 0 )
insurance
# Out:
#         sex     bmi  children smoker     region      charges
# age
# 19   female  27.900         0    yes  southwest  16884.92400
# 18     male  33.770         1     no  southeast   1725.55230
# 28     male  33.000         3     no  southeast   4449.46200
# 33     male  22.705         0     no  northwest  21984.47061
# 32     male  28.880         0     no  northwest   3866.85520
# ..      ...     ...       ...    ...        ...          ...
# 50     male  30.970         3     no  northwest  10600.54830
# 18   female  31.920         0     no  northeast   2205.98080
# 18   female  36.850         0     no  southeast   1629.83350
# 21   female  25.800         0     no  southwest   2007.94500
# 61   female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 6 columns]

# %%
insurance.head()
# Out:
#         sex     bmi  children smoker     region      charges
# age
# 19   female  27.900         0    yes  southwest  16884.92400
# 18     male  33.770         1     no  southeast   1725.55230
# 28     male  33.000         3     no  southeast   4449.46200
# 33     male  22.705         0     no  northwest  21984.47061
# 32     male  28.880         0     no  northwest   3866.85520

# %%
insurance.columns.to_list()
# Out:
# ['sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
insurance.isnull().sum()
# Out:
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 19 to 61
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sex       1338 non-null   object
#  1   bmi       1338 non-null   float64
#  2   children  1338 non-null   int64
#  3   smoker    1338 non-null   object
#  4   region    1338 non-null   object
#  5   charges   1338 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 105.5+ KB

# %%
insurance.describe()
# Out:
#                bmi     children       charges
# count  1338.000000  1338.000000   1338.000000
# mean     30.663397     1.094918  13270.422265
# std       6.098187     1.205493  12110.011237
# min      15.960000     0.000000   1121.873900
# 25%      26.296250     0.000000   4740.287150
# 50%      30.400000     1.000000   9382.033000
# 75%      34.693750     2.000000  16639.912515
# max      53.130000     5.000000  63770.428010

# %%
insurance.sample(n=3)
# Out:
#       sex    bmi  children smoker     region     charges
# age
# 30   male  24.13         1     no  northwest   4032.2407
# 47   male  19.57         1     no  northwest   8428.0693
# 60   male  24.32         0     no  northwest  12523.6048

# %%
plt.figure(figsize=(16,6))

sns.lineplot(data=insurance)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
import numpy as np

# %%
numeric_var = insurance.select_dtypes(include=[np.number]).columns.to_list()
for var in numeric_var:
    print(var)
# Out:
# bmi
# children
# charges

# %%
ax = sns.regplot(x = 'bmi', y = 'charges', data = insurance)

# %%
sns.barplot(x= insurance.index, y= insurance.charges)
plt.title('Insurance charges for children ')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.figure(figsize=(24,12))

# %%
flight_data = pd.read_csv('flight_delays.csv', index_col = 0)

# %%
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
flight_data.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
flight_data.describe()
# Out:
#               AA         AS         B6         DL         EV         F9  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean    4.120776  -1.023656   6.788370   0.231116   6.543328  13.035736
# std     3.157890   1.544310   5.543460   3.247467   3.506834   7.844315
# min    -1.432732  -3.009003  -0.709019  -5.011516   0.851062   0.082127
# 25%     2.588588  -1.864140   3.349392  -2.326739   4.719922   9.303600
# 50%     4.540731  -1.249661   5.444304   0.401224   6.707638  12.823997
# 75%     6.759151  -0.295821   9.646042   2.184623   7.927592  18.696167
# max     8.191017   2.503899  18.657673   5.614745  13.952793  27.424179
#
#               HA         MQ         NK         OO         UA        US  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  6.000000
# mean    1.993205   5.964953  14.549663   5.909658   5.413415  3.776815
# std     2.987726   7.780334   8.319500   3.380527   5.281123  2.305290
# ...

# %%
flight_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 1 to 12
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AA      12 non-null     float64
#  1   AS      12 non-null     float64
#  2   B6      12 non-null     float64
#  3   DL      12 non-null     float64
#  4   EV      12 non-null     float64
#  5   F9      12 non-null     float64
#  6   HA      12 non-null     float64
#  7   MQ      12 non-null     float64
#  8   NK      12 non-null     float64
#  9   OO      12 non-null     float64
#  10  UA      12 non-null     float64
#  11  US      6 non-null      float64
#  12  VX      12 non-null     float64
#  13  WN      12 non-null     float64
# dtypes: float64(14)
# memory usage: 1.4 KB

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(data = flight_data)
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
plt.figure(figsize= (10,5))

plt.title('Average arrival delay for MQ airlines flights by months')

sns.barplot(x= flight_data.index, y=flight_data.MQ)

plt.ylabel('Arrival delay(in minutes)')
# Out:
# Text(0, 0.5, 'Arrival delay(in minutes)')

# %%
plt.figure(figsize=(14,7))

plt.title('Average arrival delay for all airlines flights by months')

sns.heatmap(data= flight_data, annot = True)

plt.xlabel('Airlines')
# Out:
# Text(0.5, 42.0, 'Airlines')

# %%
sns.histplot(data= flight_data, x=flight_data.MQ, color = 'black')
# Out:
# <AxesSubplot:xlabel='MQ', ylabel='Count'>
